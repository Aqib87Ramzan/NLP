# %%
import spacy

# %%
from spacy.lang.en.stop_words import STOP_WORDS
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
len(STOP_WORDS)
# Out:
# 326

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp ("We just opened our wings, the flying part is coming soon")
for token in doc:
    if token.is_stop:
        print(token)
# Out:
# We
# just
# our
# the
# part
# is

# %%
def preprocess(text):
    doc = nlp(text)
    no_stop_words = [token.text for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(no_stop_words)

# %%
preprocess('We just opened our wings, the flying part is coming soon')
# Out:
# 'opened wings flying coming soon'

# %%
preprocess('the other is not other but your own brother')
# Out:
# 'brother'

# %%
preprocess('''real hardwork is necessary for getting good grades, you can't get A by doing this shit in one night''')
# Out:
# 'real hardwork necessary getting good grades shit night'

# %%
import pandas as pd

df = pd.read_json(
    r"C:\Users\hp\OneDrive - National University of Sciences & Technology\Desktop\doj_press.json",
    lines=True
)

# %%
df.head(5)
# Out:
#         id                                              title  \
# 0     None       Convicted Bomb Plotter Sentenced to 30 Years
# 1  12-919   $1 Million in Restitution Payments Announced t...
# 2  11-1002  $1 Million Settlement Reached for Natural Reso...
# 3   10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4   18-898  $100 Million Settlement Will Speed Cleanup Wor...
#
#                                             contents  \
# 0  PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# 1    WASHINGTON – North Carolina’s Waccamaw River...
# 2        BOSTON– A $1-million settlement has been...
# 3    WASHINGTON—A federal grand jury in Las Vegas...
# 4  The U.S. Department of Justice, the U.S. Envir...
#
#                         date         topics  \
# 0  2014-10-01T00:00:00-04:00             []
# 1  2012-07-25T00:00:00-04:00             []
# 2  2011-08-03T00:00:00-04:00             []
# 3  2010-01-08T00:00:00-05:00             []
# ...

# %%
df.shape
# Out:
# (13087, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of             id                                              title  \
# 0         None       Convicted Bomb Plotter Sentenced to 30 Years
# 1      12-919   $1 Million in Restitution Payments Announced t...
# 2      11-1002  $1 Million Settlement Reached for Natural Reso...
# 3       10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4       18-898  $100 Million Settlement Will Speed Cleanup Wor...
# ...        ...                                                ...
# 13082   16-735  Yuengling to Upgrade Environmental Measures to...
# 13083   10-473  Zarein Ahmedzay Pleads Guilty to Terror Violat...
# 13084   17-045  Zimmer Biomet Holdings Inc. Agrees to Pay $17....
# 13085   17-252  ZTE Corporation Agrees to Plead Guilty and Pay...
# 13086   17-304  ZTE Corporation Pleads Guilty for  Violating U...
#
#                                                 contents  \
# 0      PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# ...

# %%
df = df[df['topics'].str.len()!=0]

# %%
df.head(5)
# Out:
#          id                                              title  \
# 4    18-898  $100 Million Settlement Will Speed Cleanup Wor...
# 7   14-1412  14 Indicted in Connection with New England Com...
# 19  17-1419  2017 Southeast Regional Animal Cruelty Prosecu...
# 22  15-1562  21st Century Oncology to Pay $19.75 Million to...
# 23  17-1404  21st Century Oncology to Pay $26 Million to Se...
#
#                                              contents  \
# 4   The U.S. Department of Justice, the U.S. Envir...
# 7   A 131-count criminal indictment was unsealed t...
# 19  The United States Attorney’s Office for the Mi...
# 22  21st Century Oncology LLC, has agreed to pay $...
# 23  21st Century Oncology Inc. and certain of its ...
#
#                          date                                 topics  \
# 4   2018-07-09T00:00:00-04:00                          [Environment]
# 7   2014-12-17T00:00:00-05:00                  [Consumer Protection]
# ...

# %%
df.shape

# %%
len(df['contents'].iloc[4])

# %%
#now removing stop words for contents at 4 location
df['contents_info'] = df ['contents'].apply(preprocess)
df.head(5)

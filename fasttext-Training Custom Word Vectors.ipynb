# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\hp\OneDrive - National University of Sciences & Technology\Desktop\yo.png")  # or .png
plt.imshow(img)
plt.axis('off')  # optional: hides axes
plt.show()

# %% [markdown]
# FastText is a tool that helps computers understand words and sentences by turning them into numbers (called vectors), which can be used for tasks like:
#
# 1) Text classification (e.g., spam detection)
#
# 2) Sentiment analysis (positive/negative)
#
# 3) Finding similar words (like "king" and "queen")

# %% [markdown]
# # Difference between fasttext and word2vec

# %% [markdown]
# -- Word2Vec treats each word as a single unit.
#
# -- FastText breaks words into smaller parts (subwords) — like syllables or character n-grams.
#
# ✅ This helps FastText:
#
# 1) Understand rare or misspelled words
#
# 2) Work better with new/unseen words
#
# Example:
# The word "playing" might be broken into:
# "pla", "lay", "ayi", "yin", "ing"
# So even if the word "playinggg" appears, FastText can guess its meaning from parts.

# %%
import fasttext

# %%
# downloading english version which is trained on commeon crawl and wikipedia dataset
# https://fasttext.cc/docs/en/crawl-vectors.html

# %%
model_en = fasttext.load_model(r"C:\Users\hp\Downloads\cc.en.300.bin")

# %%
dir(model_en)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_labels',
#  '_words',
#  'f',
#  'get_analogies',
#  'get_dimension',
#  'get_input_matrix',
#  'get_input_vector',
#  'get_label_id',
#  'get_labels',
#  'get_line',
#  'get_meter',
#  'get_nearest_neighbors',
#  'get_output_matrix',
#  'get_sentence_vector',
#  'get_subword_id',
#  'get_subwords',
#  'get_word_id',
#  'get_word_vector',
#  'get_words',
#  'is_quantized',
#  'labels',
#  'predict',
#  'quantize',
#  'save_model',
#  'set_args',
#  'set_matrices',
#  'test',
#  'test_label',
#  'words']

# %%
model_en.get_nearest_neighbors('good')
# Out:
# [(0.7517593502998352, 'bad'),
#  (0.7426098585128784, 'great'),
#  (0.7299689054489136, 'decent'),
#  (0.7123614549636841, 'nice'),
#  (0.6796907186508179, 'Good'),
#  (0.6737031936645508, 'excellent'),
#  (0.669592022895813, 'goood'),
#  (0.6602178812026978, 'ggod'),
#  (0.6479219794273376, 'semi-good'),
#  (0.6417751908302307, 'good.Good')]

# %%
model_en.get_nearest_neighbors('Real')
# Out:
# [(0.6584712862968445, 'REal'),
#  (0.6302508115768433, '.Real'),
#  (0.6123827695846558, '-Real'),
#  (0.577490508556366, '1Real'),
#  (0.5699368715286255, 'real'),
#  (0.5537176728248596, 'ex-Real'),
#  (0.5492787957191467, "'Real"),
#  (0.5475876331329346, 'Esate'),
#  (0.5474712252616882, 'Realer'),
#  (0.547212541103363, 'MadridReal')]

# %%
model_en.get_nearest_neighbors('Yo')
# Out:
# [(0.734829306602478, 'yo'),
#  (0.6855024695396423, 'Ya'),
#  (0.6709718108177185, 'Yo-'),
#  (0.6420339941978455, 'Ayyy'),
#  (0.6357354521751404, 'waddup'),
#  (0.6291311979293823, 'Yooo'),
#  (0.6225035786628723, 'Yoooo'),
#  (0.6181457042694092, 'whattup'),
#  (0.608757734298706, "'Yo"),
#  (0.6070441007614136, 'Whattup')]

# %%
model_en.get_nearest_neighbors('Nigga')
# Out:
# [(0.8108280301094055, 'nigga'),
#  (0.775501549243927, 'Niggas'),
#  (0.7725355625152588, 'Niggaz'),
#  (0.727377712726593, 'niggas'),
#  (0.7148482799530029, 'Muthafucka'),
#  (0.7140056490898132, 'mothafucka'),
#  (0.7122728228569031, 'Fucc'),
#  (0.7065911889076233, 'muthafucka'),
#  (0.6984736323356628, 'Shyt'),
#  (0.691912055015564, 'gga')]

# %%
model_en.get_nearest_neighbors('yeah')
# Out:
# [(0.8245488405227661, 'geez'),
#  (0.819148600101471, 'hey'),
#  (0.8191038370132446, 'jeez'),
#  (0.8149551749229431, 'Yeah'),
#  (0.787443220615387, 'yah'),
#  (0.7768138647079468, 'yea'),
#  (0.7740577459335327, 'uhh'),
#  (0.7717912197113037, 'yup'),
#  (0.7708853483200073, 'nevermind'),
#  (0.7643594741821289, 'yep')]

# %%
model_en.get_nearest_neighbors('noway')
# Out:
# [(0.5774043202400208, 'aint'),
#  (0.5748911499977112, 'onlything'),
#  (0.5605782866477966, 'supose'),
#  (0.5595017075538635, 'nobdy'),
#  (0.5530097484588623, 'anygood'),
#  (0.5524942874908447, 'nothig'),
#  (0.5500563979148865, 'noways'),
#  (0.5495227575302124, 'noone'),
#  (0.5472016930580139, 'thats'),
#  (0.5422592163085938, 'BUt')]

# %%
model_en.get_nearest_neighbors('cato')
# Out:
# [(0.5050746202468872, 'burwell'),
#  (0.504191517829895, 'theo'),
#  (0.4841388761997223, 'ione'),
#  (0.48111429810523987, 'navarro'),
#  (0.4782092273235321, 'gideon'),
#  (0.47808146476745605, 'calloway'),
#  (0.4774271249771118, 'coe'),
#  (0.474849671125412, 'syme'),
#  (0.4745911657810211, 'tryon'),
#  (0.47285351157188416, 'kennedy')]

# %%
model_en.get_word_vector('good').shape
# Out:
# (300,)

# %%
# checking analogies
model_en.get_analogies('Pakistan', 'Islamabad', 'India')

# vec('Islamabad') - vec('Pakistan') + vec('India') ≈ ?
# it is just like Pakistan is to Islamabad as India is to ---- it should be new Delhi but due  to noisy or limitations of data, the answer is different
# Out:
# [(0.6804807782173157, 'India.But'),
#  (0.6590777635574341, 'subcontinent'),
#  (0.6555857062339783, 'sub-continent'),
#  (0.6533847451210022, 'Bangladesh'),
#  (0.6475852727890015, 'India.And'),
#  (0.6465190649032593, 'India.The'),
#  (0.6426722407341003, 'India.'),
#  (0.6413032412528992, 'India.India'),
#  (0.6387214660644531, 'India.As'),
#  (0.6380687952041626, 'Sub-continent')]

# %%
model_en.get_analogies('Islamabd', 'Pakistan', 'Berlin')
# Out:
# [(0.45625901222229004, 'Prenzlauerberg'),
#  (0.45145460963249207, 'BerlinBerlin'),
#  (0.44951963424682617, 'Berlin-Spandau'),
#  (0.44585174322128296, 'Alexanderplatz'),
#  (0.43792128562927246, 'Berlin-Wannsee'),
#  (0.4373772442340851, 'Luisenplatz'),
#  (0.42493101954460144, 'Charlottenburg-Wilmersdorf'),
#  (0.42468804121017456, 'Wilmersdorfer'),
#  (0.42369344830513, 'Kurfurstendamm'),
#  (0.4216986298561096, 'Kurfürstendamm')]

# %%
model_en.get_analogies('berlin', 'germany', 'india')
# Out:
# [(0.7148876190185547, 'delhi'),
#  (0.6974374055862427, 'mumbai'),
#  (0.648612916469574, 'jaipur'),
#  (0.6349966526031494, 'kolkata'),
#  (0.6279922723770142, 'pune'),
#  (0.6277596354484558, 'bangalore'),
#  (0.6044078469276428, 'hyderabad'),
#  (0.6021745800971985, 'noida'),
#  (0.6018899083137512, 'bhubaneswar'),
#  (0.599077582359314, 'nashik')]

# %%
model_en.get_analogies('berlin', 'germany', 'delhi')
# Out:
# [(0.6669325232505798, 'mumbai'),
#  (0.6563901901245117, 'jaipur'),
#  (0.6506325602531433, 'Delhi.'),
#  (0.6465528607368469, 'gurgaon'),
#  (0.6420154571533203, 'lucknow'),
#  (0.6405102610588074, 'delhi.'),
#  (0.63736891746521, 'chandigarh'),
#  (0.6344822645187378, 'noida'),
#  (0.6162404417991638, 'kolkata'),
#  (0.6158050894737244, 'ghaziabad')]

# %%
model_en.get_analogies('driving','car','phone')
# Out:
# [(0.610385537147522, 'texting'),
#  (0.5203558802604675, 'phone-calling'),
#  (0.5153835415840149, 'cellphone'),
#  (0.5135326981544495, 'cell-phone'),
#  (0.5117910504341125, 'dialing'),
#  (0.5087355971336365, 'texing'),
#  (0.5079342722892761, 'text-messaging'),
#  (0.500900387763977, 'txting'),
#  (0.4960441589355469, 'texting.'),
#  (0.4951859414577484, 'Texting')]

# %%
model_en.get_nearest_neighbors('chutney')
# Out:
# [(0.8078702092170715, 'chutneys'),
#  (0.7138292789459229, 'thokku'),
#  (0.701572060585022, 'Chutney'),
#  (0.6875490546226501, 'achaar'),
#  (0.684525728225708, 'piccalilli'),
#  (0.6737173199653625, 'raita'),
#  (0.6715506911277771, 'chatni'),
#  (0.6610829830169678, 'chutney.'),
#  (0.6505922675132751, 'gojju'),
#  (0.6398508548736572, 'kasundi')]

# %%
model_en.get_analogies('car', 'driving', 'texting')
# 2 -> 1 and 3 -> 4
# Out:
# [(0.5921302437782288, 'phone'),
#  (0.5862486958503723, 'cellphone'),
#  (0.5363621115684509, 'TEXTING'),
#  (0.5261636972427368, 'cell-phone'),
#  (0.5157985687255859, 'phones'),
#  (0.5031595230102539, 'txting'),
#  (0.5011012554168701, 'texter'),
#  (0.49743539094924927, 'texting.'),
#  (0.4973243474960327, 'Texting'),
#  (0.4954665005207062, 'text-message')]

# %%
model_en.get_nearest_neighbors('Pizza' , k=3)
# Out:
# [(0.7960579991340637, 'Pizzeria'),
#  (0.7805999517440796, 'Pizzas'),
#  (0.777959942817688, 'Pizza-')]

# %% [markdown]
# # General Word Embeddings for Indian Food Recipe

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\hp\OneDrive - National University of Sciences & Technology\Desktop\Cleaned_Indian_Food_Dataset.csv")

# %%
df.head(7)
# Out:
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# 5  Pudina Khara Pongal Recipe (Rice and Lentils C...
# 6         Udupi Style Ash Gourd Coconut Curry Recipe
#
#                                TranslatedIngredients  TotalTimeInMins  \
# 0  1 tablespoon Red Chilli powder,3 tablespoon Gr...               45
# 1   2 teaspoon cashew - or peanuts, 1/2 Teaspoon ...               15
# 2  1 Onion - sliced,1 teaspoon White Urad Dal (Sp...               50
# 3  1/2 teaspoon Turmeric powder (Haldi),1 tablesp...               45
# 4   oil - as per use, 1 tablespoon coriander seed...               30
# 5  1 cup Rice - soaked for 20 minutes,1 Green Chi...               30
# ...

# %%
df.TranslatedInstructions[0]
# Out:
# 'To begin making the Masala Karela Recipe,de-seed the karela and slice.\nDo not remove the skin as the skin has all the nutrients.\nAdd the karela to the pressure cooker with 3 tablespoon of water, salt and turmeric powder and pressure cook for three whistles.\nRelease the pressure immediately and open the lids.\nKeep aside.Heat oil in a heavy bottomed pan or a kadhai.\nAdd cumin seeds and let it sizzle.Once the cumin seeds have sizzled, add onions and saute them till it turns golden brown in color.Add the karela, red chilli powder, amchur powder, coriander powder and besan.\nStir to combine the masalas into the karela.Drizzle a little extra oil on the top and mix again.\nCover the pan and simmer Masala Karela stirring occasionally until everything comes together well.\nTurn off the heat.Transfer Masala Karela into a serving bowl and serve.Serve Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family.\n'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\hp\OneDrive - National University of Sciences & Technology\Desktop\34.png")  # or .png
plt.imshow(img)
plt.axis('off')  # optional: hides axes
plt.show()

# %% [markdown]
# # Using regular Expression

# %%
import re

# %%
text = 'To begin making the Masala Karela Recipe,de-seed the karela and slice.\nDo not remove the skin as the skin has all the nutrients.\nAdd the karela to the pressure cooker with 3 tablespoon of water, salt and turmeric powder and pressure cook for three whistles.\nRelease the pressure immediately and open the lids.\nKeep aside.Heat oil in a heavy bottomed pan or a kadhai.\nAdd cumin seeds and let it sizzle.Once the cumin seeds have sizzled, add onions and saute them till it turns golden brown in color.Add the karela, red chilli powder, amchur powder, coriander powder and besan.\nStir to combine the masalas into the karela.Drizzle a little extra oil on the top and mix again.\nCover the pan and simmer Masala Karela stirring occasionally until everything comes together well.\nTurn off the heat.Transfer Masala Karela into a serving bowl and serve.Serve Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family.\n'

# %%
# simply to remove special characters or . or , from the text, use regex and substitute it with space
re.sub(r"[^\w\s]", '', text, flags = re.MULTILINE)
# Out:
# 'To begin making the Masala Karela Recipedeseed the karela and slice\nDo not remove the skin as the skin has all the nutrients\nAdd the karela to the pressure cooker with 3 tablespoon of water salt and turmeric powder and pressure cook for three whistles\nRelease the pressure immediately and open the lids\nKeep asideHeat oil in a heavy bottomed pan or a kadhai\nAdd cumin seeds and let it sizzleOnce the cumin seeds have sizzled add onions and saute them till it turns golden brown in colorAdd the karela red chilli powder amchur powder coriander powder and besan\nStir to combine the masalas into the karelaDrizzle a little extra oil on the top and mix again\nCover the pan and simmer Masala Karela stirring occasionally until everything comes together well\nTurn off the heatTransfer Masala Karela into a serving bowl and serveServe Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family\n'

# %%
# example
re.sub(" +", " ", "Hi  boy these days are   good")
# Out:
# 'Hi boy these days are good'

# %%
re.sub("[ \n]+", " ", "Hi  boy these days are  \n  good")
# Out:
# 'Hi boy these days are good'

# %%
# now using above for original text
def preprocess(text):
    text = re.sub(r"[^\w\s]", '', text)
    text = re.sub(r"[ \n]+", " ", text)
    return text.strip().lower()
# it will remove any extra spaces, \n, special characters, . and , too

# %%
preprocess(text)
# Out:
# 'to begin making the masala karela recipedeseed the karela and slice do not remove the skin as the skin has all the nutrients add the karela to the pressure cooker with 3 tablespoon of water salt and turmeric powder and pressure cook for three whistles release the pressure immediately and open the lids keep asideheat oil in a heavy bottomed pan or a kadhai add cumin seeds and let it sizzleonce the cumin seeds have sizzled add onions and saute them till it turns golden brown in coloradd the karela red chilli powder amchur powder coriander powder and besan stir to combine the masalas into the kareladrizzle a little extra oil on the top and mix again cover the pan and simmer masala karela stirring occasionally until everything comes together well turn off the heattransfer masala karela into a serving bowl and serveserve masala karela along with panchmel dal and phulka for a weekday meal with your family'

# %%
df.TranslatedInstructions = df.TranslatedInstructions.map(preprocess)

# %%
df.to_csv('food_receipes.txt', columns = ['TranslatedInstructions'], header = None , index = False)

# %%
# simply now train the model for our above dataset and them compare it with back like for our some raw data some have no neighbors and now compare

# %%
model_trained = fasttext.train_unsupervised('food_receipes.txt')
# CBOW and skip-gram are unsupervised  and and for above task, this uses skip-gram

# %%
model_en.get_nearest_neighbors('chutney')
# Out:
# [(0.8078702092170715, 'chutneys'),
#  (0.7138292789459229, 'thokku'),
#  (0.701572060585022, 'Chutney'),
#  (0.6875490546226501, 'achaar'),
#  (0.684525728225708, 'piccalilli'),
#  (0.6737173199653625, 'raita'),
#  (0.6715506911277771, 'chatni'),
#  (0.6610829830169678, 'chutney.'),
#  (0.6505922675132751, 'gojju'),
#  (0.6398508548736572, 'kasundi')]

# %%
model_trained.get_nearest_neighbors('chutney')
# Out:
# [(0.9440153241157532, 'chutneys'),
#  (0.7861075401306152, 'imli'),
#  (0.7797137498855591, 'chutneyserve'),
#  (0.7616031169891357, 'dhaniya'),
#  (0.7539393901824951, 'khajur'),
#  (0.6888208985328674, 'madurai'),
#  (0.6876077055931091, 'mavinakayi'),
#  (0.6875510215759277, 'south'),
#  (0.6852356195449829, 'pudi'),
#  (0.679550290107727, 'pudina')]

# %%
model_en.get_nearest_neighbors('halwa')
# Out:
# [(0.8563978672027588, 'kheer'),
#  (0.8392286896705627, 'burfi'),
#  (0.8193163871765137, 'Halwa'),
#  (0.7894062995910645, 'kesari'),
#  (0.778471827507019, 'payasam'),
#  (0.7706475853919983, 'burfis'),
#  (0.7590622901916504, 'laddoo'),
#  (0.7504664659500122, 'ladoo'),
#  (0.7471016645431519, 'rabdi'),
#  (0.7396334409713745, 'laddu')]

# %%
model_trained.get_nearest_neighbors('halwa')
# Out:
# [(0.7399381399154663, 'rabri'),
#  (0.7335468530654907, 'burfi'),
#  (0.7326750159263611, 'khoya'),
#  (0.7103341817855835, 'khoyamawa'),
#  (0.6919914484024048, 'kheer'),
#  (0.6805146932601929, 'mohan'),
#  (0.6761428713798523, 'bhog'),
#  (0.6648269891738892, 'mawa'),
#  (0.6623905301094055, 'badam'),
#  (0.6500144600868225, 'phirni')]

# %%
model_en.get_nearest_neighbors('saragva')
# no data for this
# Out:
# [(0.5384978652000427,
#   'ReportsTabloidCrimeYakuzaTokyoGinzaIkebukuroKabukichoRoppongiShibuyaShimbashiShinjukuUenoJapanChibaFukuokaKobeKyotoNagoyaOkinawaOsakaSaitamaYokohamaSportsBaseballHorse'),
#  (0.5373231768608093,
#   'NoidaVaranasiBareillyMathuraAligarhMoradabadSaharanpurBijnorJaunpurGorakhpurMuzaffarnagarSultanpurDehradunHaridwarNainitalRoorkeeGarhwalBardhamanMurshidabadHooghlyMedinipurNorth'),
#  (0.5331498980522156,
#   '...'),
#  (0.5117493271827698,
#   'NagarMehsanaVadodaraAnandBhavnagarKachchhSabarkanthaJunagadhJamnagarGurgaonRohtakFaridabadSonepatHisarAmbalaYamuna'),
#  (0.5094584226608276, 'CityDaeguKwangjuSeoulUlsanYeosuVayama.com'),
#  (0.5093042850494385,
# ...

# %%
model_trained.get_nearest_neighbors('saragva')
# Out:
# [(0.8518491983413696, 'shahjahani'),
#  (0.8383693099021912, 'kumani'),
#  (0.828104555606842, 'kaalimirri'),
#  (0.8229033350944519, 'rasawala'),
#  (0.8193768262863159, 'fansi'),
#  (0.8189559578895569, 'kukul'),
#  (0.8176087141036987, 'shaak'),
#  (0.8158000111579895, 'veetu'),
#  (0.814712643623352, 'kalyana'),
#  (0.8091028928756714, 'kuvale')]

# %%
model_en.get_nearest_neighbors('seekh')
# Out:
# [(0.819276750087738, 'Seekh'),
#  (0.7523059844970703, 'kababs'),
#  (0.7415257692337036, 'kabab'),
#  (0.7098612189292908, 'gosht'),
#  (0.7052093744277954, 'aaloo'),
#  (0.7048103213310242, 'achari'),
#  (0.6882451772689819, 'murg'),
#  (0.688003659248352, 'bhuna'),
#  (0.685316264629364, 'gobhi'),
#  (0.6813685297966003, 'karahi')]

# %%
model_trained.get_nearest_neighbors('seekh')
# Out:
# [(0.7534319758415222, 'galouti'),
#  (0.7467128038406372, 'kabab'),
#  (0.7189721465110779, 'kfc'),
#  (0.7181701064109802, 'kebabs'),
#  (0.7104300856590271, 'kebab'),
#  (0.7101203203201294, 'sholay'),
#  (0.6947304010391235, 'haleem'),
#  (0.693787157535553, 'shikampuri'),
#  (0.6936200857162476, 'shami'),
#  (0.6872237324714661, 'legs')]

# %%
model_en.get_nearest_neighbors('moong')
# Out:
# [(0.8431017398834229, 'masoor'),
#  (0.7884171605110168, 'moongdal'),
#  (0.7828023433685303, 'urad'),
#  (0.7781772613525391, 'rajma'),
#  (0.7764648199081421, 'daal'),
#  (0.7672821283340454, 'Moong'),
#  (0.7636042237281799, 'dhal'),
#  (0.7630494832992554, 'chana'),
#  (0.7576358318328857, 'channa'),
#  (0.7477370500564575, 'tuvar')]

# %%
model_trained.get_nearest_neighbors('moong')
# Out:
# [(0.7454171180725098, 'sprouted'),
#  (0.7183424830436707, 'sprout'),
#  (0.7014471888542175, 'moth'),
#  (0.6977659463882446, 'dal'),
#  (0.6764031052589417, 'sprouts'),
#  (0.6601845622062683, 'mooga'),
#  (0.6517316102981567, 'dali'),
#  (0.6499271392822266, 'sookhi'),
#  (0.6476933360099792, 'dalia'),
#  (0.646843671798706, 'kabila')]
